# %% [markdown]
# <a href="https://colab.research.google.com/github/RaimundoAAN/Alura_Jogo/blob/main/eng_sowft_novo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
5+5*5/5
# Out:
# 10.0

# %%
a=int(input("informe um número: "))
b=int(input("informe o sugendo número: "))
print(a + b)
# Out:
# informe um número: 5
# informe o sugendo número: 5
# 10

# %%
# Questão 02
P1=float(input("Qual a nota da P1: "))
P2=float(input("Qual a nota da P2: "))
media = P1 + P2 / 2
print(f"{media}")
# Out:
# Qual a nota da P1: 5
# Qual a nota da P2: 5
# 7.5

# %%
# Questão 03
nome = input("Informe seu nome: ")
print(f"Olá {nome}!")

# %%
# Questão 05
nome = input("Informe seu nome: ")
idade = int(input(f"Olá {nome}! Você tem quantos anos ?"))
print(f" {nome * idade}")
# Out:
# Informe seu nome: neto
# Olá neto! Você tem quantos anos ?22
#  netonetonetonetonetonetonetonetonetonetonetonetonetonetonetonetonetonetonetonetonetoneto
